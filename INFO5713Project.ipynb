# %% [markdown]
# <a href="https://colab.research.google.com/github/vyshnav23/vyshnav_INFO5731_Spring2020/blob/master/INFO5713Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import glob
import pandas as pd
import os
import csv
# Select all the files in your directory
directory = r'/content/drive/My Drive/sigir_data'
files = glob.glob(directory + "/*.csv")
fields = ["article_id"]
df1 = pd.concat([pd.read_csv(fp,skipinitialspace=True, usecols=fields,encoding = "ISO-8859-1").assign(New=os.path.basename(fp)) for fp in files])
df2 = df1['article_id'].str.replace('https://doi.org/','')
df2.to_csv('output.csv')

# %%
data = pd.read_csv("output.csv") 
df1= data.dropna()
header = ["article_id"]
df1.to_csv('output.csv', columns = header)

# %%
import csv
import itertools
contents = []
with open('output.csv','r') as csvf:
    urls = csv.reader(csvf)
    next(urls, None)
    contents = [row[1] for row in itertools.islice(urls,10)] 
string = 'https://api.semanticscholar.org/v1/paper/'
my_new_list = [string+x for x in contents]
with open("Article_URLs.csv","w") as f:
    writer = csv.writer(f,delimiter="\n")
    writer.writerow(['ArticleURL'])
    writer.writerow(my_new_list)

# %%
import urllib.request
from urllib.request import Request, urlopen
from urllib.error import URLError, HTTPError
countUp = 0
headers = {}
headers['User-Agent'] = 'Mozilla/5.0 (X11; Linux i686) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1312.27 Safari/537.17'
for j in my_new_list:
 try:
     req = urllib.request.Request(j,headers=headers)
     response = urllib.request.urlopen(req)
     res=response.read().decode('utf8')
     print("Here")
     print(res)
     with open ('Article' + str(countUp) + '.json', 'w') as g:
          g.write(res)
     countUp += 1
 except HTTPError as e:
    print('The server couldn\'t fulfill the request.')
    print('Error code: ', e.code)
 except URLError as e:
    print('We failed to reach a server.')
    print('Reason: ', e.reason)
# Out:
# Here
# {"abstract":"Understanding users'search intent expressed through their search queries is crucial to Web search and online advertisement. Web query classification (QC) has been widely studied for this purpose. Most previous QC algorithms classify individual queries without considering their context information. However, as exemplified by the well-known example on query \"jaguar\", many Web queries are short and ambiguous, whose real meanings are uncertain without the context information. In this paper, we incorporate context information into the problem of query classification by using conditional random field (CRF) models. In our approach, we use neighboring queries and their corresponding clicked URLs (Web pages) in search sessions as the context information. We perform extensive experiments on real world search logs and validate the effectiveness and effciency of our approach. We show that we can improve the F1 score by 52% as compared to other state-of-the-art baselines.","arxivId":null,"authors":[{"authorId":"4205363","name":"Huanhuan Cao","url":"https://www.semanticscholar.org/author/4205363"},{"authorId":"1811433","name":"Derek Hao Hu","url":"https://www.semanticscholar.org/author/1811433"},{"authorId":"37643602","name":"Dou Shen","url":"https://www.semanticscholar.org/author/37643602"},{"authorId":"1753226","name":"Daxin Jiang","url":"https://www.semanticscholar.org/author/1753226"},{"authorId":"2084926","name":"Jian-Tao Sun","url":"https://www.semanticscholar.org/author/2084926"},{"authorId":"144378760","name":"Enhong Chen","url":"https://www.semanticscholar.org/author/144378760"},{"authorId":"152290618","name":"Qiang Yang","url":"https://www.semanticscholar.org/author/152290618"}],"citationVelocity":9,"citations":[{"arxivId":"1511.09290","authors":[{"authorId":"2266550","name":"Pedro Saleiro","url":"https://www.semanticscholar.org/author/2266550"},{"authorId":"144419509","name":"Lu\u00eds Sarmento","url":"https://www.semanticscholar.org/author/144419509"}],"doi":null,"intent":[],"isInfluential":false,"paperId":"86124e9e2376f87fde67b45fb84cc2d8bad51391","title":"\"Piaf\" vs \"Adele\": classifying encyclopedic queries using automatically labeled training data","url":"https://www.semanticscholar.org/paper/86124e9e2376f87fde67b45fb84cc2d8bad51391","venue":"OAIR","year":2013},{"arxivId":null,"authors":[{"authorId":"144609235","name":"Paul N. Bennett","url":"https://www.semanticscholar.org/author/144609235"},{"authorId":"1742466","name":"Krysta Marie Svore","url":"https://www.semanticscholar.org/author/1742466"},{"authorId":"1728602","name":"Susan T. Dumais","url":"https://www.semanticscholar.org/author/1728602"}],"doi":"10.1145/1772690.1772703","intent":["methodology"],"isInfluential":false,"paperId":"17cf2552fc88f8fa99ca913a41c5bff4958416ff","title":"Classification-enhanced ranking","url":"https://www.semanticscholar.org/paper/17cf2552fc88f8fa99ca913a41c5bff4958416ff","venue":"WWW '10","year":2010},{"arxivId":null,"authors":[{"authorId":"32710849","name":"Homa Baradaran Hashemi","url":"https://www.semanticscholar.org/author/32710849"}],"doi":null,"intent":["methodology"],"isInfluential":false,"paperId":"6a8834b7826873c62badb2c56bcfe70dfdca9dbd","title":"Query Intent Detection using Convolutional Neural Networks","url":"https://www.semanticscholar.org/paper/6a8834b7826873c62badb2c56bcfe70dfdca9dbd","venue":"","year":2016},{"arxivId":null,"authors":[{"authorId":"2002188","name":"Sai Teja Peddinti","url":"https://www.semanticscholar.org/author/2002188"},{"authorId":"144780173","name":"Nitesh Saxena","url":"https://www.semanticscholar.org/author/144780173"}],"doi":"10.3233/JCS-130491","intent":["methodology"],"isInfluential":false,"paperId":"6d18de28809c5220a1ac1303d93fa972ffa9dd9c","title":"Web search query privacy: Evaluating query obfuscation and anonymizing networks","url":"https://www.semanticscholar.org/paper/6d18de28809c5220a1ac1303d93fa972ffa9dd9c","venue":"Journal of Computer Security","year":2014},{"arxivId":null,"a ...
#
# Here
# {"abstract":"While large-scale taxonomies--especially for web pages--have been in existence for some time, approaches to automatically classify documents into these taxonomies have met with limited success compared to the more general progress made in text classification. We argue that this stems from three causes: increasing sparsity of training data at deeper nodes in the taxonomy, error propagation where a mistake made high in the hierarchy cannot be recovered, and increasingly complex decision surfaces in higher nodes in the hierarchy. While prior research has focused on the first problem, we introduce methods that target the latter two problems--first by biasing the training distribution to reduce error propagation and second by propagating up \"first-guess\" expert information in a bottom-up manner before making a refined top down choice. Finally, we present an empirical study demonstrating that the suggested changes lead to 10--30% improvements in F1 scores versus an accepted competitive baseline, hierarchical SVMs.","arxivId":null,"authors":[{"authorId":"144609235","name":"Paul N. Bennett","url":"https://www.semanticscholar.org/author/144609235"},{"authorId":"145769294","name":"Nam Nguyen","url":"https://www.semanticscholar.org/author/145769294"}],"citationVelocity":0,"citations":[{"arxivId":null,"authors":[{"authorId":"70374225","name":"Ankita A. Burungale","url":"https://www.semanticscholar.org/author/70374225"},{"authorId":"11486003","name":"Dinesh A. Zende","url":"https://www.semanticscholar.org/author/11486003"}],"doi":null,"intent":["methodology"],"isInfluential":false,"paperId":"1be430475891c8dd8d527f95e945d819785d4f0e","title":"Survey of Large-scale Hierarchical Classification","url":"https://www.semanticscholar.org/paper/1be430475891c8dd8d527f95e945d819785d4f0e","venue":"","year":2014},{"arxivId":null,"authors":[{"authorId":"2744278","name":"Andrea Addis","url":"https://www.semanticscholar.org/author/2744278"},{"authorId":"1707819","name":"Giuliano Armano","url":"https://www.semanticscholar.org/author/1707819"},{"authorId":"1738566","name":"Eloisa Vargiu","url":"https://www.semanticscholar.org/author/1738566"}],"doi":"10.5220/0003066300140023","intent":[],"isInfluential":false,"paperId":"b8fecfffc2089b4c2d5484a44241eaaed84af2df","title":"Assessing Progressive Filtering to Perform Hierarchical Text Categorization in Presence of Input Imbalance","url":"https://www.semanticscholar.org/paper/b8fecfffc2089b4c2d5484a44241eaaed84af2df","venue":"KDIR","year":2010},{"arxivId":null,"authors":[{"authorId":"1986256","name":"Rohit Babbar","url":"https://www.semanticscholar.org/author/1986256"},{"authorId":"3071383","name":"Ioannis Partalas","url":"https://www.semanticscholar.org/author/3071383"},{"authorId":"1732180","name":"\u00c9ric Gaussier","url":"https://www.semanticscholar.org/author/1732180"},{"authorId":"144444438","name":"Massih-Reza Amini","url":"https://www.semanticscholar.org/author/144444438"},{"authorId":"2621453","name":"C\u00e9cile Amblard","url":"https://www.semanticscholar.org/author/2621453"}],"doi":null,"intent":[],"isInfluential":false,"paperId":"94f4804f784d20e03adaba8f743f9e736167cfc4","title":"Learning Taxonomy Adaptation in Large-scale Classification","url":"https://www.semanticscholar.org/paper/94f4804f784d20e03adaba8f743f9e736167cfc4","venue":"J. Mach. Learn. Res.","year":2016},{"arxivId":null,"authors":[{"authorId":"50082069","name":"Lingfeng Zhang","url":"https://www.semanticscholar.org/author/50082069"},{"authorId":"144867922","name":"Shishir K. Shah","url":"https://www.semanticscholar.org/author/144867922"},{"authorId":"1706204","name":"Ioannis A. Kakadiaris","url":"https://www.semanticscholar.org/author/1706204"}],"doi":"10.5244/C.28.45","intent":["background"],"isInfluential":false,"paperId":"7f2e9cc2d57c631733b33cc68785102c39db9533","title":"Fully Associative Ensemble Learning for Hierarchical Multi-Label Classification","url":"https://www.semanticscholar.org/paper/7f2e9cc2d57c631733b33cc6 ...
#
# Here
# {"abstract":"We proposed and implemented a novel clustering algorithm called LAIR2, which has constant running time average for on-the-fly Scatter/Gather browsing [4]. Our experiments showed that when running on a single processor, the LAIR2 on-line clustering algorithm was several hundred times faster than a parallel Buckshot algorithm running on multiple processors [11]. This paper reports on a study that examined the effectiveness of the LAIR2 algorithm in terms of clustering quality and its impact on retrieval performance. We conducted a user study on 24 subjects to evaluate on-the-fly LAIR2 clustering in Scatter/Gather search tasks by comparing its performance to the Buckshot algorithm, a classic method for Scatter/Gather browsing [4]. Results showed significant differences in terms of subjective perceptions of clustering quality. Subjects perceived that the LAIR2 algorithm produced significantly better quality clusters than the Buckshot method did. Subjects felt that it took less effort to complete the tasks with the LAIR2 system, which was more effective in helping them in the tasks. Interesting patterns also emerged from subjects' comments in the final open-ended questionnaire. We discuss implications and future research.","arxivId":null,"authors":[{"authorId":"5289561","name":"Weimao Ke","url":"https://www.semanticscholar.org/author/5289561"},{"authorId":"34836211","name":"Cassidy R. Sugimoto","url":"https://www.semanticscholar.org/author/34836211"},{"authorId":"1699076","name":"Javed Mostafa","url":"https://www.semanticscholar.org/author/1699076"}],"citationVelocity":0,"citations":[{"arxivId":null,"authors":[{"authorId":"8685500","name":"Antonio Di Marco","url":"https://www.semanticscholar.org/author/8685500"},{"authorId":"1733928","name":"Roberto Navigli","url":"https://www.semanticscholar.org/author/1733928"}],"doi":"10.1162/COLI_a_00148","intent":[],"isInfluential":false,"paperId":"a86f1ce193f5bc30e485147424074e9d38c3b5c3","title":"Clustering and Diversifying Web Search Results with Graph-Based Word Sense Induction","url":"https://www.semanticscholar.org/paper/a86f1ce193f5bc30e485147424074e9d38c3b5c3","venue":"Computational Linguistics","year":2013},{"arxivId":null,"authors":[{"authorId":"2164049","name":"Ting Ting Qin","url":"https://www.semanticscholar.org/author/2164049"},{"authorId":"7483434","name":"Satoshi Fujita","url":"https://www.semanticscholar.org/author/7483434"}],"doi":"10.1109/ASONAM.2011.11","intent":["methodology"],"isInfluential":false,"paperId":"0f0b87c10d0ea4a474e36726414e100575bcb24c","title":"Automatic Tag Attachment Scheme for Efficient File Search in Peer-to-Peer File Sharing Systems","url":"https://www.semanticscholar.org/paper/0f0b87c10d0ea4a474e36726414e100575bcb24c","venue":"2011 International Conference on Advances in Social Networks Analysis and Mining","year":2011},{"arxivId":null,"authors":[{"authorId":"48094537","name":"Junjun Wang","url":"https://www.semanticscholar.org/author/48094537"},{"authorId":"3252269","name":"Guoyu Tang","url":"https://www.semanticscholar.org/author/3252269"},{"authorId":"33420715","name":"Yunqing Xia","url":"https://www.semanticscholar.org/author/33420715"},{"authorId":"144188147","name":"Qiang Zhou","url":"https://www.semanticscholar.org/author/144188147"},{"authorId":"1732885","name":"Thomas Fang Zheng","url":"https://www.semanticscholar.org/author/1732885"},{"authorId":"3009236","name":"Qinan Hu","url":"https://www.semanticscholar.org/author/3009236"},{"authorId":"35377632","name":"Sen Na","url":"https://www.semanticscholar.org/author/35377632"},{"authorId":"2165479","name":"Yaohai Huang","url":"https://www.semanticscholar.org/author/2165479"}],"doi":null,"intent":["background"],"isInfluential":false,"paperId":"69a96e3e20a28780dbb5c8af5172d3098c12c465","title":"Understanding the Query: THCIB and THUIS at NTCIR-10 Intent Task","url":"https://www.semanticscholar.org/paper/69a96e3e20a28780dbb5c8af5172d3098c12c465","venue":"NTCIR","year":2013},{"arxivId":nu ...
#
# Here
# {"abstract":"The new concept proposed in this paper is a query free web search that automatically retrieves a web page including information related to the daily activity that we are currently engaged in for automatically displaying the page on Internet-connected domestic appliances around us such as televisions. When we are washing a coffee maker, for example, a web page is retrieved that includes tips such as `cleaning a coffee maker with vinegar removes stains well.' A method designed on the basis of this concept automatically searches for a web page by using a query constructed from the use of ordinary household objects that is detected by sensors attached to the objects. An in-situ experiment tests a variety of IR techniques and the experiment confirmed that our daily activities can produce related web pages with high accuracy.","arxivId":null,"authors":[{"authorId":"34772057","name":"Takuya Maekawa","url":"https://www.semanticscholar.org/author/34772057"},{"authorId":"1704906","name":"Yutaka Yanagisawa","url":"https://www.semanticscholar.org/author/1704906"},{"authorId":"1734077","name":"Yasushi Sakurai","url":"https://www.semanticscholar.org/author/1734077"},{"authorId":"48900864","name":"Yasue Kishino","url":"https://www.semanticscholar.org/author/48900864"},{"authorId":"38746416","name":"Koji Kamei","url":"https://www.semanticscholar.org/author/38746416"},{"authorId":"1725827","name":"Takeshi Okadome","url":"https://www.semanticscholar.org/author/1725827"}],"citationVelocity":0,"citations":[{"arxivId":null,"authors":[{"authorId":"4887445","name":"Tomoya Nakatani","url":"https://www.semanticscholar.org/author/4887445"},{"authorId":"35421395","name":"Ryohei Kuga","url":"https://www.semanticscholar.org/author/35421395"},{"authorId":"34772057","name":"Takuya Maekawa","url":"https://www.semanticscholar.org/author/34772057"}],"doi":"10.1145/3282894.3289728","intent":[],"isInfluential":false,"paperId":"ef372f6a5ead95b328e9b1608af942193cd63994","title":"Object-based Activity Recognition Using Egocentric Video Based on Web Knowledge","url":"https://www.semanticscholar.org/paper/ef372f6a5ead95b328e9b1608af942193cd63994","venue":"2019 IEEE International Conference on Pervasive Computing and Communications Workshops (PerCom Workshops)","year":2018},{"arxivId":null,"authors":[{"authorId":"34772057","name":"Takuya Maekawa","url":"https://www.semanticscholar.org/author/34772057"},{"authorId":"1704906","name":"Yutaka Yanagisawa","url":"https://www.semanticscholar.org/author/1704906"},{"authorId":"1734077","name":"Yasushi Sakurai","url":"https://www.semanticscholar.org/author/1734077"},{"authorId":"48900864","name":"Yasue Kishino","url":"https://www.semanticscholar.org/author/48900864"},{"authorId":"38746416","name":"Koji Kamei","url":"https://www.semanticscholar.org/author/38746416"},{"authorId":"1725827","name":"Takeshi Okadome","url":"https://www.semanticscholar.org/author/1725827"}],"doi":"10.1145/2078316.2078320","intent":["methodology"],"isInfluential":false,"paperId":"8e4b8323b08631ddf3079659b610e7528c59b10f","title":"Context-aware web search in ubiquitous sensor environments","url":"https://www.semanticscholar.org/paper/8e4b8323b08631ddf3079659b610e7528c59b10f","venue":"TOIT","year":2012},{"arxivId":null,"authors":[{"authorId":"3165233","name":"Yefeng Liu","url":"https://www.semanticscholar.org/author/3165233"},{"authorId":"144497921","name":"Darren Edge","url":"https://www.semanticscholar.org/author/144497921"},{"authorId":"3260704","name":"Koji Yatani","url":"https://www.semanticscholar.org/author/3260704"}],"doi":"10.1145/2470654.2470750","intent":[],"isInfluential":false,"paperId":"68a0e1e017eb4dc98909af5d794ab16a9c515a86","title":"SidePoint: a peripheral knowledge panel for presentation slide authoring","url":"https://www.semanticscholar.org/paper/68a0e1e017eb4dc98909af5d794ab16a9c515a86","venue":"CHI '13","year":2013},{"arxivId":null,"authors":[{"authorId":"4887445","name":"Tomoya Nakatani","url":"https://www.semanticsch ...
#
# Here
# {"abstract":"It is now widely recognized that user interactions with search results can provide substantial relevance information on the documents displayed in the search results. In this paper, we focus on extracting relevance information from one source of user interactions, i.e., user click data, which records the sequence of documents being clicked and not clicked in the result set during a user search session. We formulate the problem as a global ranking problem, emphasizing the importance of the sequential nature of user clicks, with the goal to predict the relevance labels of all the documents in a search session. This is distinct from conventional learning to rank methods that usually design a ranking model defined on a single document; in contrast, in our model the relational information among the documents as manifested by an aggregation of user clicks is exploited to rank all the documents jointly. In particular, we adapt several sequential supervised learning algorithms, including the conditional random field (CRF), the sliding window method and the recurrent sliding window method, to the global ranking problem. Experiments on the click data collected from a commercial search engine demonstrate that our methods can outperform the baseline models for search results re-ranking.","arxivId":null,"authors":[{"authorId":"144576567","name":"Shihao Ji","url":"https://www.semanticscholar.org/author/144576567"},{"authorId":"143904275","name":"Ke Zhou","url":"https://www.semanticscholar.org/author/143904275"},{"authorId":"2922252","name":"Ciya Liao","url":"https://www.semanticscholar.org/author/2922252"},{"authorId":"1749245","name":"Zhaohui Zheng","url":"https://www.semanticscholar.org/author/1749245"},{"authorId":"1701421","name":"Gui-Rong Xue","url":"https://www.semanticscholar.org/author/1701421"},{"authorId":"1730609","name":"Olivier Chapelle","url":"https://www.semanticscholar.org/author/1730609"},{"authorId":"39864297","name":"Gordon Sun","url":"https://www.semanticscholar.org/author/39864297"},{"authorId":"145203884","name":"Hongyuan Zha","url":"https://www.semanticscholar.org/author/145203884"}],"citationVelocity":0,"citations":[{"arxivId":null,"authors":[{"authorId":"2614591","name":"Changsung Kang","url":"https://www.semanticscholar.org/author/2614591"},{"authorId":"1734449","name":"Xuanhui Wang","url":"https://www.semanticscholar.org/author/1734449"},{"authorId":"2166346","name":"Jiang Chen","url":"https://www.semanticscholar.org/author/2166346"},{"authorId":"2922252","name":"Ciya Liao","url":"https://www.semanticscholar.org/author/2922252"},{"authorId":"145882798","name":"Yi Chang","url":"https://www.semanticscholar.org/author/145882798"},{"authorId":"2409063","name":"Belle L. Tseng","url":"https://www.semanticscholar.org/author/2409063"},{"authorId":"1749245","name":"Zhaohui Zheng","url":"https://www.semanticscholar.org/author/1749245"}],"doi":"10.1145/1935826.1935924","intent":["methodology","background"],"isInfluential":false,"paperId":"342d07e9c6f1ec6a3d5871866c63fe493e79e446","title":"Learning to re-rank web search results with multiple pairwise features","url":"https://www.semanticscholar.org/paper/342d07e9c6f1ec6a3d5871866c63fe493e79e446","venue":"WSDM '11","year":2011},{"arxivId":null,"authors":[{"authorId":"49632769","name":"Mingyang Sun","url":"https://www.semanticscholar.org/author/49632769"},{"authorId":"1758230","name":"Weifeng Sun","url":"https://www.semanticscholar.org/author/1758230"},{"authorId":"1731449","name":"Lei Shu","url":"https://www.semanticscholar.org/author/1731449"},{"authorId":"1691066","name":"Mingchu Li","url":"https://www.semanticscholar.org/author/1691066"},{"authorId":"49449002","name":"Lei Xue","url":"https://www.semanticscholar.org/author/49449002"}],"doi":"10.1109/ICCNC.2012.6167463","intent":["methodology"],"isInfluential":false,"paperId":"6b0177edefbf7a916cef2adcbd83b3d5363df672","title":"FoSSicker: A personalized search engine by location-awareness","url":"https://www.seman ...
#
# Here
# {"abstract":"Query abandonment by search engine users is generally considered to be a negative signal. In this paper, we explore the concept of good abandonment. We define a good abandonment as an abandoned query for which the user's information need was successfully addressed by the search results page, with no need to click on a result or refine the query. We present an analysis of abandoned internet search queries across two modalities (PC and mobile) in three locales. The goal is to approximate the prevalence of good abandonment, and to identify types of information needs that may lead to good abandonment, across different locales and modalities. Our study has three key findings: First, queries potentially indicating good abandonment make up a significant portion of all abandoned queries. Second, the good abandonment rate from mobile search is significantly higher than that from PC search, across all locales tested. Third, classified by type of information need, the major classes of good abandonment vary dramatically by both locale and modality. Our findings imply that it is a mistake to uniformly consider query abandonment as a negative signal. Further, there is a potential opportunity for search engines to drive additional good abandonment, especially for mobile search users, by improving search features and result snippets.","arxivId":null,"authors":[{"authorId":"10150245","name":"Jane Li","url":"https://www.semanticscholar.org/author/10150245"},{"authorId":"2605572","name":"Scott B. Huffman","url":"https://www.semanticscholar.org/author/2605572"},{"authorId":"2754584","name":"Akihito Tokuda","url":"https://www.semanticscholar.org/author/2754584"}],"citationVelocity":8,"citations":[{"arxivId":null,"authors":[{"authorId":"8530169","name":"Max L. Wilson","url":"https://www.semanticscholar.org/author/8530169"}],"doi":null,"intent":["background"],"isInfluential":false,"paperId":"ba28acd43d25414f6e672dfa8c7253520eea0760","title":"An analytical inspection framework for evaluating the search tactics and user profiles supported by information seeking interfaces","url":"https://www.semanticscholar.org/paper/ba28acd43d25414f6e672dfa8c7253520eea0760","venue":"","year":2009},{"arxivId":null,"authors":[{"authorId":"34887528","name":"Dan Ionita","url":"https://www.semanticscholar.org/author/34887528"},{"authorId":"1836097","name":"Niek Tax","url":"https://www.semanticscholar.org/author/1836097"},{"authorId":"1691929","name":"Djoerd Hiemstra","url":"https://www.semanticscholar.org/author/1691929"}],"doi":null,"intent":[],"isInfluential":false,"paperId":"a0a3919c3a8962ce953cdcc6d5ee812c7c25c5b2","title":"An API-based Search System for One Click Access to Information","url":"https://www.semanticscholar.org/paper/a0a3919c3a8962ce953cdcc6d5ee812c7c25c5b2","venue":"NTCIR","year":2013},{"arxivId":null,"authors":[{"authorId":"1693190","name":"Georg Buscher","url":"https://www.semanticscholar.org/author/1693190"},{"authorId":"34286525","name":"Ryen W. White","url":"https://www.semanticscholar.org/author/34286525"},{"authorId":"1728602","name":"Susan T. Dumais","url":"https://www.semanticscholar.org/author/1728602"},{"authorId":"145522949","name":"Jeff Huang","url":"https://www.semanticscholar.org/author/145522949"}],"doi":"10.1145/2124295.2124341","intent":[],"isInfluential":false,"paperId":"9973d468d20cb75aa90d6ec82e1190dea4725fbf","title":"Large-scale analysis of individual and task differences in search result page examination strategies","url":"https://www.semanticscholar.org/paper/9973d468d20cb75aa90d6ec82e1190dea4725fbf","venue":"WSDM '12","year":2012},{"arxivId":null,"authors":[{"authorId":"1750703","name":"Ido Guy","url":"https://www.semanticscholar.org/author/1750703"}],"doi":"10.1145/2911451.2911525","intent":["background"],"isInfluential":false,"paperId":"e6d408f935668672c64a9584fa614c24e72335a5","title":"Searching by Talking: Analysis of Voice Queries on Mobile Web Search","url":"https://www.semanticscholar.org/paper/e6d408f935668 ...
#
# Here
# {"abstract":"Online advertising represents a growing part of the revenues of major Internet service providers such as Google and Yahoo. A commonly used strategy is to place advertisements (ads) on the search result pages according to the users' submitted queries. Relevant ads are likely to be clicked by a user and to increase the revenues of both advertisers and publishers. However, bid phrases defined by ad-owners are usually contained in limited number of ads. Directly matching user queries with bid phrases often results in finding few appropriate ads. To address this shortcoming, query expansion is often used to increase the chances to match the ads. Nevertheless, query expansion on top of the traditional inverted index faces efficiency issues such as high time complexity and heavy I/O costs. Moreover, precision cannot always be improved, sometimes even hurt due to the involvement of additional noise.\n In this paper, we propose an efficient ad search solution relying on a block-based index able to tackle the issues associated with query expansion. Our index structure places clusters of similar bid phrases in corresponding blocks with their associated ads. It reduces the number of merge operations significantly during query expansion and allows sequential scans rather than random accesses, saving I/O costs. We adopt flexible block sizes according to the clustering results of bid phrases to further optimize the index structure for efficient ad search. The pre-computation of such clusters is achieved through an agglomerative iterative clustering algorithm. Finally, we adapt the spreading activation mechanism to return the top-k relevant ads, improving search precision. The experimental results of our prototype, AdSearch, show that we can indeed return a larger number of relevant ads without sacrificing execution speed.","arxivId":null,"authors":[{"authorId":"7643792","name":"Haofen Wang","url":"https://www.semanticscholar.org/author/7643792"},{"authorId":"145461906","name":"Yan Liang","url":"https://www.semanticscholar.org/author/145461906"},{"authorId":"2025622","name":"Linyun Fu","url":"https://www.semanticscholar.org/author/2025622"},{"authorId":"1701421","name":"Gui-Rong Xue","url":"https://www.semanticscholar.org/author/1701421"},{"authorId":"1811427","name":"Yong Yu","url":"https://www.semanticscholar.org/author/1811427"}],"citationVelocity":0,"citations":[{"arxivId":null,"authors":[{"authorId":"2782975","name":"Ilyes Khennak","url":"https://www.semanticscholar.org/author/2782975"},{"authorId":"3321900","name":"Habiba Drias","url":"https://www.semanticscholar.org/author/3321900"}],"doi":"10.1007/s11704-016-5560-0","intent":["background"],"isInfluential":false,"paperId":"82f55f2e5e0431d23f080113f746bf7e6406f8eb","title":"Strength Pareto fitness assignment for pseudo-relevance feedback: application to MEDLINE","url":"https://www.semanticscholar.org/paper/82f55f2e5e0431d23f080113f746bf7e6406f8eb","venue":"Frontiers of Computer Science","year":2016},{"arxivId":null,"authors":[{"authorId":"49347838","name":"Miao Fan","url":"https://www.semanticscholar.org/author/49347838"},{"authorId":"9286916","name":"Jiacheng Guo","url":"https://www.semanticscholar.org/author/9286916"},{"authorId":"47474593","name":"Shuai Zhu","url":"https://www.semanticscholar.org/author/47474593"},{"authorId":"47019870","name":"Shuo Miao","url":"https://www.semanticscholar.org/author/47019870"},{"authorId":"46611108","name":"Mingming Sun","url":"https://www.semanticscholar.org/author/46611108"},{"authorId":"144785135","name":"Ping Li","url":"https://www.semanticscholar.org/author/144785135"}],"doi":"10.1145/3292500.3330651","intent":["methodology"],"isInfluential":false,"paperId":"76ea5ca2f98f0c5b09bd8611366a0fc7604f852c","title":"MOBIUS: Towards the Next Generation of Query-Ad Matching in Baidu's Sponsored Search","url":"https://www.semanticscholar.org/paper/76ea5ca2f98f0c5b09bd8611366a0fc7604f852c","venue":"KDD '19","year":2019},{"arxivId":null,"author ...
#
# Here
# {"abstract":"Pseudo-relevance feedback (PRF) via query-expansion has been proven to be e\u00aeective in many information retrieval (IR) tasks. In most existing work, the top-ranked documents from an initial search are assumed to be relevant and used for PRF. One problem with this approach is that one or more of the top retrieved documents may be non-relevant, which can introduce noise into the feedback process. Besides, existing methods generally do not take into account the significantly different types of queries that are often entered into an IR system. Intuitively, Wikipedia can be seen as a large, manually edited document collection which could be exploited to improve document retrieval effectiveness within PRF. It is not obvious how we might best utilize information from Wikipedia in PRF, and to date, the potential of Wikipedia for this task has been largely unexplored. In our work, we present a systematic exploration of the utilization of Wikipedia in PRF for query dependent expansion. Specifically, we classify TREC topics into three categories based on Wikipedia: 1) entity queries, 2) ambiguous queries, and 3) broader queries. We propose and study the effectiveness of three methods for expansion term selection, each modeling the Wikipedia based pseudo-relevance information from a different perspective. We incorporate the expansion terms into the original query and use language modeling IR to evaluate these methods. Experiments on four TREC test collections, including the large web collection GOV2, show that retrieval performance of each type of query can be improved. In addition, we demonstrate that the proposed method out-performs the baseline relevance model in terms of precision and robustness.","arxivId":null,"authors":[{"authorId":"39418120","name":"Yang Xu","url":"https://www.semanticscholar.org/author/39418120"},{"authorId":"143723939","name":"Gareth J. F. Jones","url":"https://www.semanticscholar.org/author/143723939"},{"authorId":"37722675","name":"Bin Wang","url":"https://www.semanticscholar.org/author/37722675"}],"citationVelocity":13,"citations":[{"arxivId":null,"authors":[{"authorId":"145269114","name":"Jeffrey Dalton","url":"https://www.semanticscholar.org/author/145269114"},{"authorId":"145798498","name":"Laura Dietz","url":"https://www.semanticscholar.org/author/145798498"},{"authorId":"144890574","name":"James Allan","url":"https://www.semanticscholar.org/author/144890574"}],"doi":"10.1145/2600428.2609628","intent":["methodology","background"],"isInfluential":false,"paperId":"f0a11dd98d96bb0765bc87925add7d5566f97adb","title":"Entity query feature expansion using knowledge base links","url":"https://www.semanticscholar.org/paper/f0a11dd98d96bb0765bc87925add7d5566f97adb","venue":"SIGIR '14","year":2014},{"arxivId":null,"authors":[{"authorId":"1780941","name":"Wouter Weerkamp","url":"https://www.semanticscholar.org/author/1780941"},{"authorId":"1680484","name":"Krisztian Balog","url":"https://www.semanticscholar.org/author/1680484"},{"authorId":"1696030","name":"Maarten de Rijke","url":"https://www.semanticscholar.org/author/1696030"}],"doi":"10.1145/2382616.2382621","intent":[],"isInfluential":false,"paperId":"dca1185d77b4d8e880a370f0c1f472fea845de4c","title":"Exploiting External Collections for Query Expansion","url":"https://www.semanticscholar.org/paper/dca1185d77b4d8e880a370f0c1f472fea845de4c","venue":"TWEB","year":2012},{"arxivId":null,"authors":[{"authorId":"144847172","name":"Gilad Katz","url":"https://www.semanticscholar.org/author/144847172"},{"authorId":"1779353","name":"Anna Shtok","url":"https://www.semanticscholar.org/author/1779353"},{"authorId":"1779654","name":"Oren Kurland","url":"https://www.semanticscholar.org/author/1779654"},{"authorId":"1762969","name":"Bracha Shapira","url":"https://www.semanticscholar.org/author/1762969"},{"authorId":"1732091","name":"Lior Rokach","url":"https://www.semanticscholar.org/author/1732091"}],"doi":"10.1145/2600428.2609553","intent":[],"isInfluential":f ...
#
# Here
# {"abstract":"We examine two basic sources for implicit relevance feedback on the segment level for search personalization: eye tracking and display time. A controlled study has been conducted where 32 participants had to view documents in front of an eye tracker, query a search engine, and give explicit relevance ratings for the results. We examined the performance of the basic implicit feedback methods with respect to improved ranking and compared their performance to a pseudo relevance feedback baseline on the segment level and the original ranking of a Web search engine.\n Our results show that feedback based on display time on the segment level is much coarser than feedback from eye tracking. But surprisingly, for re-ranking and query expansion it did work as well as eye-tracking-based feedback. All behavior-based methods performed significantly better than our non-behavior-based baseline and especially improved poor initial rankings of the Web search engine.\n The study shows that segment-level display time yields comparable results as eye-tracking-based feedback. Thus, it should be considered in future personalization systems as an inexpensive but precise method for implicit feedback.","arxivId":null,"authors":[{"authorId":"1693190","name":"Georg Buscher","url":"https://www.semanticscholar.org/author/1693190"},{"authorId":"1727962","name":"Ludger van Elst","url":"https://www.semanticscholar.org/author/1727962"},{"authorId":"145279674","name":"Andreas Dengel","url":"https://www.semanticscholar.org/author/145279674"}],"citationVelocity":0,"citations":[{"arxivId":null,"authors":[{"authorId":"118022865","name":"Leena Dhangar","url":"https://www.semanticscholar.org/author/118022865"},{"authorId":"2431621","name":"Amol Dnyaneshwar Potgantwar","url":"https://www.semanticscholar.org/author/2431621"}],"doi":null,"intent":["methodology","background"],"isInfluential":false,"paperId":"f0d4963c6713548c2b216457d9ed18ff71a74629","title":"User Action Interpretation for Online Content Optimization","url":"https://www.semanticscholar.org/paper/f0d4963c6713548c2b216457d9ed18ff71a74629","venue":"","year":2014},{"arxivId":null,"authors":[{"authorId":"2417334","name":"Michael Gamon","url":"https://www.semanticscholar.org/author/2417334"},{"authorId":"1990190","name":"Patrick Pantel","url":"https://www.semanticscholar.org/author/1990190"}],"doi":null,"intent":["methodology"],"isInfluential":false,"paperId":"e1d3b7b9c1bde8b29a1d5df2d907fab69c376e4c","title":"Understanding Document Aboutness Step Two: Identifying Interesting Things","url":"https://www.semanticscholar.org/paper/e1d3b7b9c1bde8b29a1d5df2d907fab69c376e4c","venue":"","year":2014},{"arxivId":null,"authors":[{"authorId":"2568110","name":"Dmitry Lagun","url":"https://www.semanticscholar.org/author/2568110"},{"authorId":"1684032","name":"Mounia Lalmas","url":"https://www.semanticscholar.org/author/1684032"}],"doi":"10.1145/2835776.2835833","intent":["methodology"],"isInfluential":false,"paperId":"44c990cdec924eedbea7d21e39452cb6b0e4f3bd","title":"Understanding and Measuring User Engagement and Attention in Online News Reading","url":"https://www.semanticscholar.org/paper/44c990cdec924eedbea7d21e39452cb6b0e4f3bd","venue":"WSDM '16","year":2016},{"arxivId":null,"authors":[{"authorId":"2168105","name":"Konstantinos C. Apostolakis","url":"https://www.semanticscholar.org/author/2168105"},{"authorId":"1747572","name":"Petros Daras","url":"https://www.semanticscholar.org/author/1747572"}],"doi":"10.1007/s00371-013-0903-4","intent":[],"isInfluential":false,"paperId":"5c271b5f96cfce1b4fdacc728ae8f8ebcbc738f9","title":"A framework for implicit human-centered image tagging inspired by attributed affect","url":"https://www.semanticscholar.org/paper/5c271b5f96cfce1b4fdacc728ae8f8ebcbc738f9","venue":"The Visual Computer","year":2013},{"arxivId":null,"authors":[{"authorId":"1703337","name":"Milad Shokouhi","url":"https://www.semanticscholar.org/author/1703337"},{"authorId":"145461473","name":"Qi Guo"," ...
#
# Here
# {"abstract":"The selection of indexing terms for representing documents is a key decision that limits how effective subsequent retrieval can be. Often stemming algorithms are used to normalize surface forms, and thereby address the problem of not finding documents that contain words related to query terms through infectional or derivational morphology. However, rule-based stemmers are not available for every language and it is unclear which methods for coping with morphology are most effective. In this paper we investigate an assortment of techniques for representing text and compare these approaches using data sets in eighteen languages and five different writing systems.\n We find character n-gram tokenization to be highly effective. In half of the languages examined n-grams outperform unnormalized words by more than 25%; in highly infective languages relative improvements over 50% are obtained. In languages with less morphological richness the choice of tokenization is not as critical and rule-based stemming can be an attractive option, if available. We also conducted an experiment to uncover the source of n-gram power and a causal relationship between the morphological complexity of a language and n-gram effectiveness was demonstrated.","arxivId":null,"authors":[{"authorId":"145324163","name":"Paul McNamee","url":"https://www.semanticscholar.org/author/145324163"},{"authorId":"144440349","name":"Charles K. Nicholas","url":"https://www.semanticscholar.org/author/144440349"},{"authorId":"145510552","name":"James Mayfield","url":"https://www.semanticscholar.org/author/145510552"}],"citationVelocity":0,"citations":[{"arxivId":null,"authors":[{"authorId":"145324163","name":"Paul McNamee","url":"https://www.semanticscholar.org/author/145324163"}],"doi":null,"intent":["background"],"isInfluential":false,"paperId":"8a3459f84b967c8a983bdf1b055ff92ed2400d06","title":"JHU Experiments in Monolingual Farsi Document Retrieval at CLEF 2009","url":"https://www.semanticscholar.org/paper/8a3459f84b967c8a983bdf1b055ff92ed2400d06","venue":"CLEF","year":2009},{"arxivId":null,"authors":[{"authorId":null,"name":"Tesfa Kebede Hundesa","url":null},{"authorId":"82432950","name":"Addis Ababa","url":"https://www.semanticscholar.org/author/82432950"},{"authorId":"2702103","name":"Dida Midekso","url":"https://www.semanticscholar.org/author/2702103"},{"authorId":null,"name":"Netsanet Kebede","url":null}],"doi":null,"intent":["background"],"isInfluential":false,"paperId":"ae709bc11654e0ef3e8785b9ea8ebd01cf17dfb7","title":"A THESIS SUBMITTED TO THE SCHOOL OF GRADUATE STUDIES OF ADDIS ABABA UNIVERSITY IN PARTIAL FULFILLMENT FOR THE DEGREE OF MASTERS OF SCIENCE IN COMPUTER SCIENCE","url":"https://www.semanticscholar.org/paper/ae709bc11654e0ef3e8785b9ea8ebd01cf17dfb7","venue":"","year":2010},{"arxivId":null,"authors":[{"authorId":"145324163","name":"Paul McNamee","url":"https://www.semanticscholar.org/author/145324163"}],"doi":null,"intent":["background"],"isInfluential":false,"paperId":"31df6aa61d438d4342974dfc4bd1483a5aaf2829","title":"A Domain Independent Approach to Clinical Decision Support","url":"https://www.semanticscholar.org/paper/31df6aa61d438d4342974dfc4bd1483a5aaf2829","venue":"TREC","year":2015},{"arxivId":null,"authors":[{"authorId":"2071527","name":"Jiaul H. Paik","url":"https://www.semanticscholar.org/author/2071527"},{"authorId":"2771134","name":"Dipasree Pal","url":"https://www.semanticscholar.org/author/2771134"},{"authorId":"144219620","name":"Swapan K. Parui","url":"https://www.semanticscholar.org/author/144219620"}],"doi":"10.1145/2009916.2010031","intent":["methodology","background"],"isInfluential":false,"paperId":"7c8d9a14fe6758aa704d7df6b8cf0637e3e1d66f","title":"A novel corpus-based stemming algorithm using co-occurrence statistics","url":"https://www.semanticscholar.org/paper/7c8d9a14fe6758aa704d7df6b8cf0637e3e1d66f","venue":"SIGIR '11","year":2011},{"arxivId":null,"authors":[{"authorId":"3252869","name":"Jes\u00fas Vilares","url ...

# %%
#table 1
import json
import pandas
from pandas import DataFrame
Venuelist = []
Titlelist = []
Yearlist = []
Abstractlist = []
Doilist = []
FieldsOfStudylist = []
Topiclist = []
urllist = []
influentialCitationCountlist = []
for i in range(10):
  f = open('Article' + str(i) + '.json')
  data = json.load(f)
  venue = data['venue']
  Venuelist.append(venue)
  title = data['title']
  Titlelist.append(title)
  year = data['year']
  Yearlist.append(year)
  abstract = data['abstract']
  Abstractlist.append(abstract)
  doi = data['doi']
  Doilist.append(doi)
  fieldsOfStudy = data['fieldsOfStudy']
  FieldsOfStudylist.append(fieldsOfStudy)
  influentialCitationCount = data['influentialCitationCount']
  influentialCitationCountlist.append(influentialCitationCount)
  for value in data['topics']:
    topic = value['topic']
    Topiclist.append(topic)
  url = data['url']
  urllist.append(url)   
f.close()

# %%
import pandas as pd
import glob
import pandas as pd
import os
# Select all the files in your directory
directory = r'/content/drive/My Drive/sigir_data'
files = glob.glob(directory + "/*.csv")
fields = ["article_id","pdf_link","total_citation","total_download","pdf_link"]
df1 = pd.concat([pd.read_csv(fp,skipinitialspace=True, usecols=fields,encoding = "ISO-8859-1") for fp in files])
pdflinklist = df1['pdf_link'].values.tolist()
totalcitationlist = df1['total_citation'].values.tolist()
totaldownloadlist = df1['total_download'].values.tolist()
articleidlist = df1['article_id'].values.tolist()
col_list = ["article_id"]
dfarticle = pd.read_csv("output.csv", usecols=col_list)
doilist = dfarticle['article_id'].values.tolist()
a = {'Article_id' : articleidlist ,'Venue' : Venuelist ,'Title' : Titlelist ,'Year' :Yearlist, 'Abstract': Abstractlist,
     'Doi' : doilist,'fieldsOfStudy' : FieldsOfStudylist,'Downloadurl' : pdflinklist,
     'TotalCitationCount' : totalcitationlist, 'TotalDownloadCount' : totaldownloadlist, 'Influentialcitationcount' : influentialCitationCountlist}
df = pd.DataFrame.from_dict(a, orient='index')
#df['fieldsOfStudy'].str.strip('[]').astype(int)
df1 = df.transpose()
#df1['fieldsOfStudy'] = df1['fieldsOfStudy'].str.strip('[]')
df1
# Out:
#                                    Article_id  ... Influentialcitationcount
# 0     https://doi.org/10.1145/1571941.1571945  ...                        5
# 1     https://doi.org/10.1145/1571941.1571946  ...                       17
# 2     https://doi.org/10.1145/1571941.1571947  ...                        1
# 3     https://doi.org/10.1145/1571941.1571949  ...                        0
# 4     https://doi.org/10.1145/1571941.1571950  ...                        0
# ...                                       ...  ...                      ...
# 1090  https://doi.org/10.1145/2348283.2348538  ...                     None
# 1091  https://doi.org/10.1145/2348283.2348539  ...                     None
# 1092  https://doi.org/10.1145/2348283.2348540  ...                     None
# 1093  https://doi.org/10.1145/2348283.2348541  ...                     None
# 1094  https://doi.org/10.1145/2348283.2348542  ...                     None
#
# [1095 rows x 11 columns]

# %%
#table 2
import json
import pandas
from pandas import DataFrame
authorIdlist = []
authorname = []
authorurl = []
#authorrank = []
#authorinstitution = []
#authorPublication = []
for i in range(10):
  f = open('Article' + str(i) + '.json')
  data = json.load(f)
  for value in data['authors']:
    authorId = value['authorId']
    authorIdlist.append(authorId) 
  for value in data['authors']:
    name = value['name']
    authorname.append(name) 
  for value in data['authors']:
    url = value['url']
    authorurl.append(url)
f.close()

# %%
import pandas as pd
import glob
import pandas as pd
import os
# Select all the files in your directory
directory = r'/content/drive/My Drive/sigir_data'
files = glob.glob(directory + "/*.csv")
df1 = pd.concat([pd.read_csv(fp,skipinitialspace=True, usecols=fields,encoding = "ISO-8859-1") for fp in files])
dfarticle = pd.read_csv("output.csv", usecols=col_list)
a = {'authorId' : authorIdlist ,'name' : authorname ,'url' : authorurl }
df = pd.DataFrame.from_dict(a, orient='index')
df1 = df.transpose()
df1
# Out:
#      authorId  ...                                               url
# 0     4205363  ...    https://www.semanticscholar.org/author/4205363
# 1     1811433  ...    https://www.semanticscholar.org/author/1811433
# 2    37643602  ...   https://www.semanticscholar.org/author/37643602
# 3     1753226  ...    https://www.semanticscholar.org/author/1753226
# 4     2084926  ...    https://www.semanticscholar.org/author/2084926
# 5   144378760  ...  https://www.semanticscholar.org/author/144378760
# 6   152290618  ...  https://www.semanticscholar.org/author/152290618
# 7   144609235  ...  https://www.semanticscholar.org/author/144609235
# 8   145769294  ...  https://www.semanticscholar.org/author/145769294
# 9     5289561  ...    https://www.semanticscholar.org/author/5289561
# 10   34836211  ...   https://www.semanticscholar.org/author/34836211
# 11    1699076  ...    https://www.semanticscholar.org/author/1699076
# 12   34772057  ...   https://www.semanticscholar.org/author/34772057
# 13    1704906  ...    https://www.semanticscholar.org/author/1704906
# 14    1734077  ...    https://www.semanticscholar.org/author/1734077
# 15   48900864  ...   https://www.semanticscholar.org/author/48900864
# 16   38746416  ...   https://www.semanticscholar.org/author/38746416
# 17    1725827  ...    https://www.semanticscholar.org/author/1725827
# 18  144576567  ...  https://www.semanticscholar.org/author/144576567
# 19  143904275  ...  https://www.semanticscholar.org/author/143904275
# 20    2922252  ...    https://www.semanticscholar.org/author/2922252
# 21    1749245  ...    https://www.semanticscholar.org/author/1749245
# 22    1701421  ...    https://www.semanticscholar.org/author/1701421
# 23    1730609  ...    https://www.semanticscholar.org/author/1730609
# 24   39864297  ...   https://www.semanticscholar.org/author/39864297
# 25  145203884  ...  https://www.semanticscholar.org/author/145203884
# 26   10150245  ...   https://www.semanticscholar.org/author/10150245
# 27    2605572  ...    https://www.semanticscholar.org/author/2605572
# 28    2754584  ...    https://www.semanticscholar.org/author/2754584
# 29    7643792  ...    https://www.semanticscholar.org/author/7643792
# 30  145461906  ...  https://www.semanticscholar.org/author/145461906
# 31    2025622  ...    https://www.semanticscholar.org/author/2025622
# 32    1701421  ...    https://www.semanticscholar.org/author/1701421
# 33    1811427  ...    https://www.semanticscholar.org/author/1811427
# 34   39418120  ...   https://www.semanticscholar.org/author/39418120
# 35  143723939  ...  https://www.semanticscholar.org/author/143723939
# 36   37722675  ...   https://www.semanticscholar.org/author/37722675
# 37    1693190  ...    https://www.semanticscholar.org/author/1693190
# 38    1727962  ...    https://www.semanticscholar.org/author/1727962
# 39  145279674  ...  https://www.semanticscholar.org/author/145279674
# 40  145324163  ...  https://www.semanticscholar.org/author/145324163
# 41  144440349  ...  https://www.semanticscholar.org/author/144440349
# 42  145510552  ...  https://www.semanticscholar.org/author/145510552
#
# [43 rows x 3 columns]

# %%
#table 3
import json
import pandas
from pandas import DataFrame
citingpaperId = []
citingdoi = []
citingtitle = []
citingvenue = []
citingyear = []
citingintent = []
citinginfluential = []
for i in range(10):
  f = open('Article' + str(i) + '.json')
  data = json.load(f)
  for value in data['citations']:
    paperId = value['paperId']
    citingpaperId.append(paperId)
    #print(paperId)
    doi = value['doi']
    citingdoi.append(doi)
    #print(doi)
    title = value['title']
    citingtitle.append(title)
    #print(title)
    venue = value['venue']
    citingvenue.append(venue)
    #print(venue)
    year = value['year']
    citingyear.append(year)
    #print(year)
    intent = value['intent']
    citingintent.append(intent)
    #print(intent)
    isInfluential = value['isInfluential']
    citinginfluential.append(isInfluential) 
    #print(isInfluential)
a = {'paperId' : citingpaperId ,'doi' : citingdoi ,'title' : citingtitle ,
     'venue' :citingvenue, 'year': citingyear,
     'intent' : citingintent,'isInfluential' : citinginfluential}
df = pd.DataFrame.from_dict(a, orient='index')
df1 = df.transpose()
df1
# Out:
#                                       paperId  ... isInfluential
# 0    86124e9e2376f87fde67b45fb84cc2d8bad51391  ...         False
# 1    17cf2552fc88f8fa99ca913a41c5bff4958416ff  ...         False
# 2    6a8834b7826873c62badb2c56bcfe70dfdca9dbd  ...         False
# 3    6d18de28809c5220a1ac1303d93fa972ffa9dd9c  ...         False
# 4    52affb7f959b42eecccfce180b4c53da0b0d5161  ...         False
# ..                                        ...  ...           ...
# 651  ccf847b7ff6418b7b07d7661db806aa7bc398d49  ...         False
# 652  b1ecd03dde90e3d1343ccb5f6e1a43c59e85fc96  ...         False
# 653  e902e17cc21050c412579015a70b3213298db6eb  ...         False
# 654  81f5e1e91e986ac942f8d1e134d3de6a1f4f98d1  ...          True
# 655  f195c3ae86143f71c08a26f61c79e6423ad740bc  ...         False
#
# [656 rows x 7 columns]

# %%
#table 4
import re
referencepaperidlist = []
Referencepaperdoilist = []
Referencepapertitlelist = []
Referencepapervenuelist = []
Referencepaperyearlist = []
Isinfluentiallist = [] 
Intentlist = []
for i in range(10):
  f = open('Article' + str(i) + '.json')
  data = json.load(f)
  for value in data['references']:
    referencepaperid = value['paperId']
    referencepaperidlist.append(referencepaperid)
    referencepaperdoi = value['doi']
    Referencepaperdoilist.append(referencepaperdoi)
    Referencepapertitle = value['title']
    Referencepapertitlelist.append(Referencepapertitle)
    Referencepapervenue = value['venue']
    Referencepapervenuelist.append(Referencepapervenue)
    Referencepaperyear = value['year']
    Referencepaperyearlist.append(Referencepaperyear)
    Intent = value['intent']
    Intentlist.append(Intent)
    Isinfluential = value['isInfluential']
    Isinfluentiallist.append(Isinfluential)
a = {'Reference_paper_id' : referencepaperidlist ,'Reference _paper_doi' : Referencepaperdoilist ,'Reference _paper_title' : Referencepapertitlelist ,
     'Reference _paper_venue' :Referencepapervenuelist, 'Reference _paper_year': Referencepaperyearlist,
     'Intent' : Intentlist,'Is_influential' : Isinfluentiallist}
df = pd.DataFrame.from_dict(a, orient='index')
df1 = df.transpose()
df1
# Out:
#                            Reference_paper_id  ... Is_influential
# 0    0f66ae3575cd750ec24fd89d5b5f6c17fcf40e22  ...          False
# 1    d25b816de84af3493aa2899baa4eb4d539e188c9  ...          False
# 2    81ff98c24470348e3eaf1c7c456a66557c852299  ...          False
# 3    a903aed9c83a85950a9661dffae2ffd30d65782a  ...          False
# 4    8990e097dfe7db7df892250e3309f3ed59fef023  ...          False
# ..                                        ...  ...            ...
# 225  f49cc1b64ed6adf3725a20dcc4f475da747729fc  ...          False
# 226  2f235dfc93539bca986cc377bbff445ce6a56ad1  ...          False
# 227  79b0c22855bab4d4e70abe08dd7ae55407bffd7c  ...           True
# 228  61e60ef022143e30807219f31530725ea473b7bc  ...          False
# 229  912f55fd2f8164ef5a3ffca770861e6a285835ea  ...          False
#
# [230 rows x 7 columns]
