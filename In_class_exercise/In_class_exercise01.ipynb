# %% [markdown]
# <a href="https://colab.research.google.com/github/vyshnav23/vyshnav_INFO5731_Spring2020/blob/master/In_class_exercise/In_class_exercise01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# my first python code

# %%
a=23
print(a)
# Out:
# 23
